# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# 1. Load the datasets
train_df = pd.read_csv('train_data.csv')
test_df = pd.read_csv('test_data.csv')

# 2. Preprocessing
train_df['shortlisted'] = train_df['shortlisted'].map({'Yes': 1, 'No': 0})
test_df['shortlisted'] = test_df['shortlisted'].map({'Yes': 1, 'No': 0})

train_df = pd.get_dummies(train_df, columns=['education_level'], drop_first=True)
test_df = pd.get_dummies(test_df, columns=['education_level'], drop_first=True)

# Ensure consistent columns
for col in set(train_df.columns) - set(test_df.columns):
    test_df[col] = 0
test_df = test_df[train_df.columns]

X_train = train_df.drop('shortlisted', axis=1)
y_train = train_df['shortlisted']
X_test = test_df.drop('shortlisted', axis=1)
y_test = test_df['shortlisted']

# 3. Apply KNN Model (using 5 neighbors)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

# 4. Predict
y_pred = knn.predict(X_test)

# 5. Evaluate Performance
accuracy = accuracy_score(y_test, y_pred)
print(f"KNN Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# KNN Accuracy: 0.8525
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.75      0.76      1832
#            1       0.89      0.90      0.89      4168
#
#     accuracy                           0.85      6000
#    macro avg       0.83      0.82      0.83      6000
# weighted avg       0.85      0.85      0.85      6000

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# 1. Load the datasets
train_df = pd.read_csv('train_data.csv')
test_df = pd.read_csv('test_data.csv')

# 2. Preprocessing
train_df['shortlisted'] = train_df['shortlisted'].map({'Yes': 1, 'No': 0})
test_df['shortlisted'] = test_df['shortlisted'].map({'Yes': 1, 'No': 0})

train_df = pd.get_dummies(train_df, columns=['education_level'], drop_first=True)
test_df = pd.get_dummies(test_df, columns=['education_level'], drop_first=True)

# Ensure test set columns match training set
for col in set(train_df.columns) - set(test_df.columns):
    test_df[col] = 0
test_df = test_df[train_df.columns]

X_train = train_df.drop('shortlisted', axis=1)
y_train = train_df['shortlisted']
X_test = test_df.drop('shortlisted', axis=1)
y_test = test_df['shortlisted']

# 3. Apply Decision Tree Model
dtree = DecisionTreeClassifier(random_state=42)
dtree.fit(X_train, y_train)

# 4. Predict
y_pred = dtree.predict(X_test)

# 5. Evaluate Performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Decision Tree Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Decision Tree Accuracy: 0.8490
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75      1832
#            1       0.89      0.90      0.89      4168
#
#     accuracy                           0.85      6000
#    macro avg       0.82      0.82      0.82      6000
# weighted avg       0.85      0.85      0.85      6000

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# 1. Load the datasets
train_df = pd.read_csv('train_data.csv')
test_df = pd.read_csv('test_data.csv')

# 2. Preprocessing
train_df['shortlisted'] = train_df['shortlisted'].map({'Yes': 1, 'No': 0})
test_df['shortlisted'] = test_df['shortlisted'].map({'Yes': 1, 'No': 0})

train_df = pd.get_dummies(train_df, columns=['education_level'], drop_first=True)
test_df = pd.get_dummies(test_df, columns=['education_level'], drop_first=True)

for col in set(train_df.columns) - set(test_df.columns):
    test_df[col] = 0
test_df = test_df[train_df.columns]

X_train = train_df.drop('shortlisted', axis=1)
y_train = train_df['shortlisted']
X_test = test_df.drop('shortlisted', axis=1)
y_test = test_df['shortlisted']

# 3. Feature Scaling (Crucial for SVM performance)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 4. Apply SVM Model
# We use a linear kernel to keep it comparable to Logistic Regression
svm_model = SVC(kernel='linear', random_state=42)
svm_model.fit(X_train_scaled, y_train)

# 5. Predict
y_pred = svm_model.predict(X_test_scaled)

# 6. Evaluate Performance
accuracy = accuracy_score(y_test, y_pred)
print(f"SVM Accuracy: {accuracy}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# SVM Accuracy: 0.8908333333333334
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      1832
#            1       0.92      0.93      0.92      4168
#
#     accuracy                           0.89      6000
#    macro avg       0.87      0.87      0.87      6000
# weighted avg       0.89      0.89      0.89      6000
